# %%
from scipy import stats
import pandas as pd 
import numpy as np
import math

# %% [markdown]
# ##  Formula
#
# Level of Significance = (1+Confidence Level) / 2 <br>
# Test for no. of Success = (x-np)/sqrt(npq)

# %% [markdown]
# ###  Problem Statement 2:
# The college bookstore tells prospective students that the average cost of its
# textbooks is Rs. 52 with a standard deviation of Rs. 4.50. A group of smart statistics
# students thinks that the average cost is higher. To test the bookstore’s claim against
# their alternative, the students will select a random sample of size 100. Assume that
# the mean from their random sample is Rs. 52.80. Perform a hypothesis test at the
# 5% level of significance and state your decision.

# %%
u = 52
h0 = 52
std_dev = 4.50
n = 100
x = 52.80

#h1 > 52
alpha_level_LOS = 0.05


z  = (x-u)/(std_dev/math.sqrt(n))
z

print('Since this is a one tails test with 5% level of significance which means critical point would be 1.65. Since z-statistics value 1.78 is less than 1.65, we can reject null  hypothesis.')
print('Reject Null Hypothesis')
print(z)
#Since this is a one tails test with 5% level of significance which means critical point would be 1.65. Since z-statistics value
# 1.78 is greater than 1.65, we can  reject null  hypothesis.
# Out:
# Since this is a one tails test with 5% level of significance which means critical point would be 1.65. Since z-statistics value 1.78 is less than 1.65, we can reject null  hypothesis.
# Reject Null Hypothesis
# 1.7777777777777715

# %% [markdown]
# ### Problem Statement 3:
# A certain chemical pollutant in the Genesee River has been constant for several
# years with mean μ = 34 ppm (parts per million) and standard deviation σ = 8 ppm. A
# group of factory representatives whose companies discharge liquids into the river is
# now claiming that they have lowered the average with improved filtration devices. A
# group of environmentalists will test to see if this is true at the 1% level of
# significance. Assume that their sample of size 50 gives a mean of 32.5 ppm.
# Perform a hypothesis test at the 1% level of significance and state your decision.

# %%
u = 34
h0 = 34
std_dev = 8
n = 50
x = 32.5

h1 = x
alpha_level = 0.01

z  = (x-u)/(std_dev/math.sqrt(n))
z

print('Do Not reject Null Hypothesis')
print(z)
print('Since this is a one tail test with 1% level of significance which means critical point would be -2.33. Since z-statistics value is lesser than -2.33, we can not reject the null hypothesis.')

#Since this is a one tail test with 1% level of significance which means critical point would be -2.33. Since z-statistics value
# is lesser than -2.33, we can not reject the null hypothesis.
#It is probably not due to random chance.
# Out:
# Do Not reject Null Hypothesis
# -1.3258252147247767
# Since this is a one tail test with 1% level of significance which means critical point would be -2.33. Since z-statistics value is lesser than -2.33, we can not reject the null hypothesis.

# %%
z
# Out:
# -1.3258252147247767

# %% [markdown]
# ## Video Suggestions

# %% [markdown]
# https://www.youtube.com/watch?v=7kb-a7n2bcQ <br>
# https://www.youtube.com/watch?v=zJ8e_wAWUzE <br>
# https://www.youtube.com/watch?v=xgxKFmBBj3U

# %% [markdown]
# ### Problem Statement 4:
# Based on population figures and other general information on the U.S. population,
# suppose it has been estimated that, on average, a family of four in the U.S. spends
# about $1135 annually on dental expenditures. Suppose further that a regional dental
# association wants to test to determine if this figure is accurate for their area of
# country. To test this, 22 families of 4 are randomly selected from the population in
# that area of the country and a log is kept of the family’s dental expenditure for one
# year. The resulting data are given below. Assuming, that dental expenditure is
# normally distributed in the population, use the data and an alpha of 0.5 to test the
# dental association’s hypothesis.
# 1008, 812, 1117, 1323, 1308, 1415, 831, 1021, 1287, 851, 930, 730, 699,
# 872, 913, 944, 954, 987, 1695, 995, 1003, 994

# %%
u = 1135
n = 22
alpha = 0.01

x = [1008, 812, 1117, 1323, 1308, 1415, 831, 1021, 1287, 851, 930, 730, 699, 872, 913, 944, 954, 987, 1695, 995, 1003, 994]
s = np.std(x)
mean_ = np.mean(x)

a= (mean_-u)
b = (s/math.sqrt(n))
t = a/b

deg_free = n-1
print('Since t calculated value i.e',t,'is less that t tabulated values at significance level of 1% i.e. -2.5176. This means we can accept our null hypothesis')
print(t)
# Out:
# Since t calculated value i.e -2.070747228595759 is less that t tabulated values at significance level of 1% i.e. -2.5176. This means we can accept our null hypothesis
# -2.070747228595759

# %% [markdown]
# ### Problem Statement 5:
# In a report prepared by the Economic Research Department of a major bank the
# Department manager maintains that the average annual family income on Metropolis
# is 48,432.
# What do you conclude about the validity of the report if a random sample
# of 400 families shows and average income of $48,574 with a standard deviation of
# 2000?

# %%
u = 48432
n = 400 
x = 48574
s = 2000
alpha = 0.05


z  = (x-u)/(s/math.sqrt(n))
z

print('Accept Null Hypothesis')
print('Since z calculated values i.e.',z,'is less than z tabulated value i.e. 1.65. This means we should accept null hypothesis')
z
# Out:
# Accept Null Hypothesis
# Since z calculated values i.e. 1.42 is less than z tabulated value i.e. 1.65. This means we should accept null hypothesis
# 1.42

# %% [markdown]
# ### Problem Statement 6:
# Suppose that in past years the average price per square foot for warehouses in the
# United States has been 32.28. A national real estate investor wants to determine
# whether that figure has changed now. The investor hires a researcher who randomly
# samples 19 warehouses that are for sale across the United States and finds that the
# mean price per square foot is 31.67, with a standard deviation of $1.29. assume
# that the prices of warehouse footage are normally distributed in population. If the
# researcher uses a 5% level of significance, what statistical conclusion can be
# reached? What are the hypotheses?

# %%
u = 32.28
n = 19
x = 31.67
s = 1.29
alpha = 0.05


z  = (x-u)/(s/math.sqrt(n))
z

print('Reject Null Hypothesis')
print('Since z calculated values i.e.',z,'is greater than z tabulated value i.e. -1.65. This means we should reject null hypothesis')
z
# Out:
# Reject Null Hypothesis
# Since z calculated values i.e. -2.06118477175179 is greater than z tabulated value i.e. -1.65. This means we should reject null hypothesis
# -2.06118477175179
